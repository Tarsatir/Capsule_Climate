# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('result_data/household_quantiles.csv')
df.head()
# Out:
#     I_mean_20   I_mean_80  I_mean_100  W_mean_20  W_mean_80  W_mean_100  \
# 0  191.371726  321.509230  522.098607  46.031112  78.561732  167.715887
# 1  194.491022  308.876325  496.189287  48.784348  79.781057  166.488705
# 2  201.747637  310.653933  497.496755  48.560899  76.785187  159.806177
# 3  208.204563  310.020635  494.087555  49.556505  75.027264  156.236298
# 4  214.348690  310.771430  495.894858  51.038588  74.042628  154.646090
#
#    α_Y_mean_20  α_Y_mean_80  α_Y_mean_100  α_W_mean_20  α_W_mean_80  \
# 0      0.81579     0.815487      0.804351      0.81821     0.815453
# 1      0.80581     0.805487      0.794371      0.80823     0.805453
# 2      0.81523     0.815367      0.804052      0.81765     0.815347
# 3      0.82389     0.825137      0.813693      0.82630     0.825107
# 4      0.82939     0.833353      0.821627      0.83176     0.833317
#
#    α_W_mean_100
# 0      0.802006
# 1      0.792026
# 2      0.801667
# 3      0.811347
# 4      0.819351

# %%
df[['α_W_mean_20', 'α_W_mean_80', 'α_W_mean_100']].plot()
plt.show()

# %%
df[['α_Y_mean_20', 'α_Y_mean_80', 'α_Y_mean_100']].plot()
plt.show()
