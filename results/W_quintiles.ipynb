# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('result_data/household_quantiles.csv')
df.head()
# Out:
#     I_mean_20   I_mean_80  I_mean_100  W_mean_20   W_mean_80  W_mean_100  \
# 0  159.160255  249.819832  380.638440  59.587679  152.800699  303.333495
# 1  163.573036  254.904143  392.065542  57.946220  149.684612  297.064055
# 2  165.516292  258.659623  400.318815  54.776179  144.411388  287.417577
# 3  166.892823  255.681505  389.285998  54.169055  141.763053  280.118253
# 4  170.446181  259.720499  397.209278  52.947390  139.076393  274.512641
#
#    α_Y_mean_20  α_Y_mean_80  α_Y_mean_100  α_W_mean_20  α_W_mean_80  \
# 0      0.74646     0.670067      0.585729      0.75600     0.667597
# 1      0.75644     0.680067      0.595639      0.76598     0.677597
# 2      0.76555     0.689187      0.604920      0.77519     0.686657
# 3      0.75586     0.679297      0.595150      0.76522     0.676860
# 4      0.76531     0.688777      0.604830      0.77479     0.686287
#
#    α_W_mean_100
# 0      0.583613
# 1      0.593523
# 2      0.602884
# 3      0.593114
# 4      0.602834

# %%
df[['α_W_mean_20', 'α_W_mean_80', 'α_W_mean_100']].plot()
plt.show()

# %%
df[['α_Y_mean_20', 'α_Y_mean_80', 'α_Y_mean_100']].plot()
plt.show()
